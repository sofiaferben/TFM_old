# %% [markdown]
# # DDinter
#
# https://ddinter.scbdd.com/ he descargado todo esto
# ![image.png](attachment:7b40a99a-22ce-4d3c-b0d8-eb8be560fddc.png)

# %%
import pandas as pd
df_code_A = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_A.csv")
df_code_B = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_B.csv")
df_code_D = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_D.csv")
df_code_H = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_H.csv")
df_code_L = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_L.csv")
df_code_P = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_P.csv")
df_code_R = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_R.csv")
df_code_V = pd.read_csv(r"C:/Users/Usuario/Desktop/TFM/datos/ddinter/ddinter_downloads_code_V.csv")

# %%
df_code_A
# Out:
#        DDInterID_A                Drug_A  DDInterID_B  \
# 0      DDInter1263            Naltrexone     DDInter1
# 1         DDInter1              Abacavir  DDInter1348
# 2        DDInter58    Aluminum hydroxide   DDInter582
# 3       DDInter112            Aprepitant   DDInter582
# 4       DDInter138           Attapulgite   DDInter582
# ...            ...                   ...          ...
# 56362  DDInter1022          Lansoprazole   DDInter888
# 56363  DDInter1675           Simvastatin   DDInter888
# 56364  DDInter1906  Ursodeoxycholic acid   DDInter888
# 56365  DDInter1318              Nystatin  DDInter1097
# 56366  DDInter1622          Rosuvastatin  DDInter1097
#
#                         Drug_B     Level
# 0                     Abacavir  Moderate
# 1                     Orlistat  Moderate
# 2                 Dolutegravir     Major
# 3                 Dolutegravir     Minor
# 4                 Dolutegravir     Major
# ...                        ...       ...
# ...
