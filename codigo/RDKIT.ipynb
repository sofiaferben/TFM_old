# %% [markdown]
# **RDKIT**
#
# Use RDKIT to encode smiles into a something readable by the code

# %%
#conda install -c conda-forge rdkit
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\K6502\anaconda3\envs\TFM
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          48 KB  conda-forge
#     brotli-1.1.0               |       h2466b09_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       h2466b09_2          20 KB  conda-forge
#     ca-certificates-2025.4.26  |       h4c7d964_0         149 KB  conda-forge
#     cairo-1.18.4               |       h5782bbf_0         1.5 MB  conda-forge
#     certifi-2025.1.31          |     pyhd8ed1ab_0         159 KB  conda-forge
#     chardet-5.2.0              |     pyhd8ed1ab_3         129 KB  conda-forge
# ...

# %%
from rdkit import Chem

smiles = 'CC(=O)OC1=CC=CC=C1C(=O)O'  # Example: Aspirin
mol = Chem.MolFromSmiles(smiles)

# %%
from rdkit.Chem import Descriptors

features = [
    Descriptors.MolWt(mol),           # Molecular Weight
    Descriptors.MolLogP(mol),         # LogP (lipophilicity)
    Descriptors.NumHDonors(mol),      # Number of H-bond donors
    Descriptors.NumHAcceptors(mol),   # Number of H-bond acceptors
    Descriptors.TPSA(mol),            # Topological Polar Surface Area
]
print(features)
# Out:
# [180.15899999999996, 1.3101, 1, 3, 63.60000000000001]

# %%
from rdkit.Chem import AllChem
import numpy as np

fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=2048)
fp_array = np.array(fp)
print(fp_array)
# Out:
# [0 0 0 ... 0 0 0]
# [15:02:47] DEPRECATION WARNING: please use MorganGenerator

# %% [markdown]
# for now we are not going to use it
